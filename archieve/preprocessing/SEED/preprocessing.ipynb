# %% [markdown]
# # Load

# %% [markdown]
# # Structure

# %% [markdown]
# # Preprocess

# %%
# Perhaps only get features and put in a table, the band separation thing is a question mark yet

# %% [markdown]
# # Save
