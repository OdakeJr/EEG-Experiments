# %%
"""
from pathlib import Path

from moabb.datasets import Weibo2014, Zhou2020
from moabb.datasets import Schirrmeister2017


WEIBO_PATH = Path("../../Datasets/Weibo2014/original")
ZHOU_PATH = Path("../../Datasets/Zhou2020/original")
SCHIRRMEISTER_PATH = Path("../../Datasets/Schirrmeister2017/original")


def download_weibo2014(path=WEIBO_PATH):
    path = Path(path)

    if not path.exists():
        raise FileNotFoundError(f"Path does not exist: {path.resolve()}")

    Weibo2014().download(
        subject_list=None,
        path=str(path),
        force_update=False,
        update_path=False,
    )

    print("✅ Weibo2014 downloaded.")


def download_zhou2020(path=ZHOU_PATH):
    path = Path(path)

    if not path.exists():
        raise FileNotFoundError(f"Path does not exist: {path.resolve()}")

    Zhou2020().download(
        subject_list=None,
        path=str(path),
        force_update=False,
        update_path=False,
    )

    print("✅ Zhou2020 downloaded.")
    
def download_schirrmeister2017(path=SCHIRRMEISTER_PATH):
    path = Path(path)

    if not path.exists():
        raise FileNotFoundError(
            f"Path does not exist: {path.resolve()}"
        )

    dataset = Schirrmeister2017()

    dataset.download(
        subject_list=None,
        path=str(path),
        force_update=False,
        update_path=False,
    )

    print("✅ Schirrmeister2017 downloaded.")
    
    
download_schirrmeister2017()    # 10-20 + Gb
download_zhou2020()             # 10-20 + Gb
"""

# %%
# Out:
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/site-packages/moabb/datasets/download.py:97: RuntimeWarning: Setting non-standard config type: "MNE_DATASETS_ZHOU2020_PATH"
#   set_config(key, get_config("MNE_DATA"))
# ...
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'zenodo.org'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 100%|██████████████████████████████████████| 1.14G/1.14G [00:00<00:00, 119GB/s]
# SHA256 hash of downloaded file: 897c8316ac8130635821cab42d39b946dcedf54a582f3252bf028e190f294dbf
# Use this value as the 'known_hash' argument of 'pooch.retrieve' to ensure that the file hasn't changed if it is downloaded again in the future.
# ...
