# %% [markdown]
# Define a variable space

# %% [markdown]
# We need to find relations of P1->P2 and perhaps p2->P1
# - We need to define the “->” operation
# - We need to define the selection of P1 and P2
# - It is lower bounded

# %% [markdown]
# Whats next
