# %%
# PARAMETERS
"""
PATHS = {...}
DATA_CONFIG = {...}
PREPROCESSING_CONFIG = {...}
DOMAIN_CONFIGS = [...]
ANALYSIS_CONFIG = {...}
TRAINING_CONFIG = {...}
EVALUATION_CONFIG = {...}
RANDOM_SEEDS = [...]
"""

# %%
# LOAD DATA
# 1 - JUST NEED TO TAKE THE CLASSES OR FUNCTIONS OF THE INDIVIDUAL LOADERS

# %%
# ======== DEFINE LOOP ==========

# %%
# PREPARE DATA

# %%
# DOMAIN CONSTRUCTION

# %%
# DOMAIN ANALYSIS

# %%
# MODEL TRAINING

# %%
# EVALUATION

# %%
# PLOT IS PROBABLY ON ANOTHER SCRIPT

# %%
# STORAGE
