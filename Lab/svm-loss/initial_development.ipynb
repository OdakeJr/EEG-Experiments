# %%
import numpy as np

# %% [markdown]
# ### Load or generate data

# %% [markdown]
# ### Structure data X, y, D

# %% [markdown]
# ### Create function to train one class SVM

# %% [markdown]
# ### Create network with SVM loss

# %% [markdown]
# ### Create routine to train all SVM

# %% [markdown]
# ### Create routine to do iterative train-test

# %% [markdown]
# ### Show results
