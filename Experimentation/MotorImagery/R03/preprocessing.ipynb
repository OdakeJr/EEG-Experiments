# %%
import sys
import os
from pathlib import Path

import pandas as pd

sys.path.append(os.path.abspath("../../../"))
PROJECT_ROOT = "../../../"

from preprocessing.MotorImagery.preprocessing import (
    load_bci_iv_2a_data
)
from preprocessing.general.filtering import (
    apply_filters_to_dataset,
    bands
)
import preprocessing.general.feature_extraction as fe


# ============================================================
# Paths
# ============================================================

root_gdf = os.path.join(
    PROJECT_ROOT,
    "Datasets/MotorImagery/original/BCICIV_2a_gdf/"
)

root_mat = os.path.join(
    PROJECT_ROOT,
    "Datasets/MotorImagery/original/true_labels/"
)

output_csv = Path(
    os.path.join(
        PROJECT_ROOT,
        "Datasets/MotorImagery/processed/bci_features.csv"
    )
)


# ============================================================
# Channel configuration
# ============================================================
"""
selected_channels = [
    "Fz",
    "FC3",
    "FC1",
    "FCz",
    "FC2",
    "FC4",
    "C5",
    "C3",
    "C1",
    "Cz",
    "C2",
    "C4",
    "C6",
    "CP3",
    "CP1",
    "CPz",
    "CP2",
    "CP4",
    "P1",
    "Pz",
    "P2",
    "POz",
]
"""

# Select a specific electrode configuration.
selected_channels = [
    "C3",
    "Cz",
    "C4",
]

# Use this instead to keep all 22 BCI EEG channels:
# selected_channels = None


# ============================================================
# Feature configuration
# ============================================================

extract_config = {
    "mean": {"function": fe.extract_mean},
    "std": {"function": fe.extract_std},
    "mom": {"function": fe.extract_moments},
    "min": {"function": fe.extract_min},
    "max": {"function": fe.extract_max},
    "cov": {"function": fe.extract_covariance},
    "eig": {"function": fe.extract_eigenvalues},

    # "logcov": {
    #     "function": fe.extract_logcov
    # },

    # "fft": {
    #     "function": fe.extract_fft,
    #     "params": {"ntop": 5},
    # },

    "h_diff": {"function": fe.extract_halves_diff},
    "q_stats": {"function": fe.extract_quarters_stats},
    "logvar": {"function": fe.extract_logvar},
}


# ============================================================
# Load data
# ============================================================

all_data = load_bci_iv_2a_data(
    root_gdf=root_gdf,
    root_mat=root_mat,
    config={
        "channels": selected_channels,
    },
)

print("✅ Finished loading all subjects and sessions.")


# ============================================================
# Filtering and resampling
# ============================================================

filtered_data = apply_filters_to_dataset(
    dataset=all_data,
    config={
        "original_fs": 250,
    },
)

print("✅ Filtering complete.")


# ============================================================
# Feature extraction
# ============================================================

df_features = fe.extract_features_to_dataframe(
    dataset=filtered_data,
    extract_config=extract_config,
    band_labels=bands,
)

print("✅ Feature extraction complete.")
print(df_features.shape)
display(df_features.head())


# ============================================================
# Save features
# ============================================================

output_csv.parent.mkdir(
    parents=True,
    exist_ok=True,
)

df_features.to_csv(
    output_csv,
    index=False,
)

print(f"✅ Saved to: {output_csv}")
# Out:
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
# /Users/edsonodake/miniforge3/envs/svm_env/lib/python3.10/contextlib.py:142: RuntimeWarning: Channel names are not unique, found duplicates for: {'EEG'}. Applying running numbers for duplicates.
#   next(self.gen)
-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.6916239626681657e-13
#   log_cov = scipy.linalg.logm(cov)
# ...
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.5320274673440196e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.471454838021101e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.673695857371307e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.4588959788662154e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.2658873817850184e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.782007246432296e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.29551573877719e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.9336422772529803e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.834628943548494e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 3.1194858419863876e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.5038710440034125e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.8584100706122174e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.8121499538309447e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.2902759321430615e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.9126571235074527e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.995978426681355e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.354089717332295e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 3.0738230599645765e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.3601153578762077e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.6390623335895794e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.5487615147204723e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.6329089445120257e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.457235766923067e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.836303024257563e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.3172015444185673e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.7297245379425853e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.602386327745297e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.562119761399752e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.617473428864141e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.625139588242744e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.57913790908759e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.539060343432498e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.5828688937938926e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.7595881447204037e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.473405189359021e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.555152902285979e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.495538999842133e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.2584710966630688e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.685650375758668e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.943289158337128e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.675309280173188e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.4340524245007496e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.2713814209740874e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.4068704039349173e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.500423909290021e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.433848063788695e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.549753908702423e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.464827260133456e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.6457111765003284e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.357980006548165e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.950327067065643e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.3797288062813183e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.7518729141225593e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.606388070479671e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.5323054529704195e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.561895420133887e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.524322588236755e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.481548345190579e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.49167177869693e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.5192950667255165e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.2703194760506934e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.3319814839911966e-13
#   log_cov = scipy.linalg.logm(cov)
# /Users/edsonodake/Documents/2026/Code Paper 2/preprocessing/general/feature_extraction.py:131: RuntimeWarning: logm result may be inaccurate, approximate err = 2.539729984061468e-13
#   log_cov = scipy.linalg.logm(cov)
# Subjects: 100%|██████████| 9/9 [00:35<00:00,  3.94s/it]
# ✅ Feature extraction complete.
# (5184, 1587)
#   subject   session  label  b8_12_mean_0  b8_12_mean_1  b8_12_mean_2  \
# 0     A01  session1      3  2.380351e-09  1.733224e-08  9.291380e-09
# 1     A01  session1      2  5.360754e-09  1.111883e-08  2.111726e-09
# 2     A01  session1      1  2.613426e-08  1.955509e-08  2.923330e-08
# 3     A01  session1      0 -2.354679e-10 -8.663889e-09 -7.688249e-09
# 4     A01  session1      0  1.278455e-09  1.361218e-08  1.067621e-08
#
#    b8_12_mean_3  b8_12_mean_4  b8_12_mean_5  b8_12_mean_6  ...  \
# 0  4.750105e-09 -4.489676e-09 -8.144126e-09  4.656935e-10  ...
# 1  1.618129e-08  5.970768e-09  1.422088e-08  1.835344e-08  ...
# 2  2.318268e-08  2.419033e-08  9.921166e-09  2.172376e-08  ...
# 3 -6.171389e-09 -1.202778e-09  2.668830e-09 -1.457442e-08  ...
# 4  1.595427e-08  8.368821e-10 -2.031881e-09 -3.366320e-09  ...
#
#    b13_30_logvar_12  b13_30_logvar_13  b13_30_logvar_14  b13_30_logvar_15  \
# 0        -25.187830        -25.044827        -24.994819        -24.918954
# 1        -25.250484        -25.262670        -25.195872        -25.144321
# 2        -25.189467        -25.272543        -25.242723        -25.123802
# 3        -25.413412        -25.065231        -25.032799        -24.997628
# 4        -25.160603        -25.293436        -25.238383        -25.097954
#
#    b13_30_logvar_16  b13_30_logvar_17  b13_30_logvar_18  b13_30_logvar_19  \
# 0        -24.897370        -24.826096        -25.067700        -24.979655
# 1        -25.104484        -24.889848        -25.114417        -25.048282
# 2        -25.139476        -25.155704        -25.211929        -25.092936
# 3        -25.140768        -25.254054        -24.937564        -24.935948
# 4        -25.181959        -25.163388        -25.133852        -25.051318
#
#    b13_30_logvar_20  b13_30_logvar_21
# 0        -24.907722        -24.815178
# 1        -25.019555        -24.819314
# 2        -25.112987        -24.934424
# 3        -25.031548        -24.746900
# 4        -25.071441        -24.730564
#
# [5 rows x 1587 columns]
# ✅ Saved to: ../../../Datasets/MotorImagery/processed/bci_features.csv
