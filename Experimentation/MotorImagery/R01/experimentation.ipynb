# %% [markdown]
# # Load

# %%
import pandas as pd
import numpy as np

# %%
df_features = pd.read_csv("../../Datasets/MotorImagery/processed/bci_features.csv")
df_features.head()
# Out:
#   subject   session  label      time_0_0      time_0_1      time_0_2  \
# 0     A01  session1      3  5.267527e-11  4.034399e-11  4.678092e-11
# 1     A01  session1      2  4.258623e-11  3.805907e-11  4.301141e-11
# 2     A01  session1      1  3.245072e-11  2.707170e-11  3.160530e-11
# 3     A01  session1      0  5.061837e-11  4.290988e-11  4.819076e-11
# 4     A01  session1      0  2.911876e-11  2.147890e-11  2.556846e-11
#
#        time_0_3      time_0_4      time_0_5      time_0_6  ...    freq_18_18  \
# 0  4.988477e-11  4.692093e-11  4.089548e-11  1.548455e-11  ...  1.046879e-10
# 1  4.352206e-11  4.202700e-11  3.613776e-11  2.298732e-11  ...  9.521127e-11
# 2  3.281442e-11  3.181356e-11  2.884676e-11  1.674429e-11  ...  5.976102e-11
# 3  4.964892e-11  4.569411e-11  3.962393e-11  2.052034e-11  ...  8.840444e-11
# 4  2.738989e-11  2.745035e-11  2.583514e-11  1.027371e-11  ...  7.598676e-11
#
#      freq_18_19    freq_18_20    freq_18_21    freq_19_19    freq_19_20  \
# ...

# %% [markdown]
# # Define Benchmark Models

# %%
import numpy as np

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# Optional boosters
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier

# %%
# I believe the full model must be condensed here, including processing adjustments, and so on

# %% [markdown]
# # Classical Methods

# %%
def train_lda(X_train, y_train):
    model = LinearDiscriminantAnalysis()
    model.fit(X_train, y_train)
    return model

def train_logistic_regression(X_train, y_train, C=1.0, max_iter=1000):
    model = LogisticRegression(
        C=C,
        max_iter=max_iter,
        solver="lbfgs",
        n_jobs=-1
    )
    model.fit(X_train, y_train)
    return model

def train_svm_linear(X_train, y_train, C=1.0):
    model = SVC(
        kernel="linear",
        C=C,
        probability=False
    )
    model.fit(X_train, y_train)
    return model

def train_svm_rbf(X_train, y_train, C=1.0, gamma="scale"):
    model = SVC(
        kernel="rbf",
        C=C,
        gamma=gamma,
        probability=False
    )
    model.fit(X_train, y_train)
    return model

def train_knn(X_train, y_train, n_neighbors=5, weights="distance"):
    model = KNeighborsClassifier(
        n_neighbors=n_neighbors,
        weights=weights,
        n_jobs=-1
    )
    model.fit(X_train, y_train)
    return model

def train_random_forest(
    X_train,
    y_train,
    n_estimators=300,
    max_depth=None,
    random_state=42
):
    model = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        random_state=random_state,
        n_jobs=-1
    )
    model.fit(X_train, y_train)
    return model

def train_xgboost(
    X_train,
    y_train,
    n_estimators=300,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
):
    model = XGBClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        learning_rate=learning_rate,
        subsample=subsample,
        colsample_bytree=colsample_bytree,
        objective="binary:logistic",
        eval_metric="logloss",
        use_label_encoder=False,
        random_state=random_state,
        n_jobs=-1
    )
    model.fit(X_train, y_train)
    return model

# %%
from sklearn.metrics import accuracy_score

def evaluate_model(model, X, y):
    y_pred = model.predict(X)
    return accuracy_score(y, y_pred)

# %% [markdown]
# # Domain Aware

# %%
# Domain Aware
# - DANN (Domain-Adversarial Neural Network)
# - MMD-based alignment
# - CORAL / Deep CORAL
# - GroupDRO

# %% [markdown]
# # Principled Losses

# %%
# I need only a loss study with one MLP with different losses
# - ERM (Empirical Risk Minimization)
# - IRM (Invariant Risk Minimization)
# - VREx (Variance Risk Extrapolation)
# - SRM (Structural Risk Minimization)
# - LUSI (But different, it is not risk, not regularization)
# - My method should be LUSI related, but instead of samples I should do features!!!

# %%
# - Domain randomization (Data augmentation ?????)

# %% [markdown]
# # Define Novel Model

# %%
# Proposed
# - I
# - Don't
# - Know
# - Yet

# %% [markdown]
# # Define Whole Set of Experiments

# %%
# Intra subject testing
# Inter subject testing
# - Leave one out
# - Train with N and test in M

# %%
# Inter dataset testing???

# %%
# Iterative testing for mean and variance in sthocastic models

# %%
# Experiments with aspescts that limit the dataset
# - Less subjects
# - Less data per subject
# - Less electrodes
# - Additional noise?

# %% [markdown]
# # Save Everything
